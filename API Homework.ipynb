# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import requests

api_key = "44f5560dedda3c03d5e175cafdb1f686"

from citipy import citipy

output_data_file = "Desktop/cities.csv"

lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
lat_lngs = []
cities = []

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 625

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

print("Beginning Data Retrieval")
print("------------------------")

city_data = []

i = 0

for city in cities:
    i += 1
    try:
        print("Processing record " + str(i) + " of Set 1: " + str(city))
        query_url = url + "appid=" + api_key + "&q=" + city
        weather_response = requests.get(query_url)
        weather_json = weather_response.json()
        city_data.append(weather_json)
    except KeyError:
        print("City not found... skipping")

print("-----------------------")
print("Data Retrieval Complete")
print("-----------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing record 1 of Set 1: williams lake
# Processing record 2 of Set 1: olimpia
# Processing record 3 of Set 1: east london
# Processing record 4 of Set 1: san policarpo
# Processing record 5 of Set 1: kazalinsk
# Processing record 6 of Set 1: jawhar
# Processing record 7 of Set 1: plouzane
# Processing record 8 of Set 1: bagan
# Processing record 9 of Set 1: hilo
# Processing record 10 of Set 1: pyu
# Processing record 11 of Set 1: portland
# Processing record 12 of Set 1: ushuaia
# Processing record 13 of Set 1: mahebourg
# Processing record 14 of Set 1: victoria
# Processing record 15 of Set 1: punta arenas
# Processing record 16 of Set 1: quang ngai
# Processing record 17 of Set 1: santa ana
# Processing record 18 of Set 1: rikitea
# Processing record 19 of Set 1: merrill
# Processing record 20 of Set 1: fortuna
# Processing record 21 of Set 1: lapua
# Processing record 22 of Set 1: warren
# ...

# %%
city_data
# Out:
# [{'coord': {'lon': -122.14, 'lat': 52.13},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 293.15,
#    'pressure': 1019,
#    'humidity': 49,
#    'temp_min': 293.15,
#    'temp_max': 293.15},
#   'visibility': 24140,
#   'wind': {'speed': 3.1, 'deg': 280},
#   'clouds': {'all': 75},
#   'dt': 1562885812,
#   'sys': {'type': 1,
#    'id': 970,
#    'message': 0.0064,
#    'country': 'CA',
#    'sunrise': 1562846462,
#    'sunset': 1562905599},
#   'timezone': -25200,
#   'id': 6182212,
#   'name': 'Williams Lake',
#   'cod': 200},
#  {'coord': {'lon': 8.54, 'lat': 44.99},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 295.15,
#    'pressure': 1012,
#    'humidity': 65,
#    'temp_min': 292.04,
#    'temp_max': 298.15},
#   'visibility': 10000,
# ...

# %%
temperature_list = []
lat_list = []

for city in city_data:
    try:
        temperature_list.append(city['main']['temp'])
        lat_list.append(city['coord']['lat'])
        
    except KeyError:
        None
    

temperature_list
# Out:
# [293.15,
#  295.15,
#  285.7,
#  298.3,
#  298.7,
#  290.13,
#  288.1,
#  300.12,
#  296.2,
#  292.17,
#  276.15,
#  292.83,
#  297.57,
#  278.15,
#  298.7,
#  314.64,
#  296.3,
#  302.93,
#  292.11,
#  279.88,
#  300.75,
#  280,
#  301.02,
#  292.85,
#  280.93,
#  286.81,
#  287.05,
#  292.06,
#  294.15,
#  279.53,
#  296.15,
#  301.15,
#  296.3,
#  281.9,
#  292.9,
#  289.79,
#  296.76,
#  277,
#  282.9,
#  287.15,
#  290.15,
#  297.9,
#  302.1,
#  284.15,
#  289.07,
#  286.24,
#  298.15,
#  299.4,
#  282.76,
#  278.4,
#  288.5,
#  286.4,
#  297.15,
#  286.1,
#  306.2,
#  296.1,
#  300.6,
#  301.25,
#  294.15,
#  290.52,
#  292.08,
#  278.2,
#  291.3,
#  295.2,
#  297.7,
#  294.5,
#  292.9,
#  307.15,
#  302.03,
#  295.4,
#  298.6,
#  304.84,
#  297.24,
#  294.15,
#  303.71,
#  291.3,
#  290.37,
#  274.5,
#  292.7,
#  293.5,
#  289.3,
#  294.52,
#  287.15,
#  281.3,
#  297.15,
#  296.8,
#  285.8,
#  293.39,
#  280.15,
#  289,
#  296.7,
#  295,
#  299.6,
#  287.15,
#  293.4,
# ...

# %%
humidity_list = []
lat_list2 = []

for city in city_data:
    try:
        humidity_list.append(city['main']['humidity'])
        lat_list2.append(city['coord']['lat'])
        
    except KeyError:
        None
    

humidity_list
# Out:
# [49,
#  65,
#  76,
#  92,
#  92,
#  93,
#  80,
#  54,
#  96,
#  93,
#  93,
#  88,
#  88,
#  86,
#  73,
#  19,
#  80,
#  30,
#  77,
#  81,
#  37,
#  75,
#  74,
#  88,
#  81,
#  100,
#  93,
#  93,
#  83,
#  99,
#  49,
#  74,
#  68,
#  76,
#  37,
#  59,
#  100,
#  95,
#  81,
#  58,
#  51,
#  57,
#  73,
#  81,
#  93,
#  96,
#  94,
#  45,
#  87,
#  94,
#  98,
#  73,
#  78,
#  94,
#  36,
#  76,
#  77,
#  22,
#  77,
#  93,
#  77,
#  66,
#  73,
#  70,
#  92,
#  40,
#  77,
#  46,
#  79,
#  86,
#  31,
#  55,
#  78,
#  73,
#  45,
#  84,
#  80,
#  94,
#  88,
#  89,
#  99,
#  88,
#  93,
#  48,
#  100,
#  98,
#  94,
#  88,
#  100,
#  63,
#  59,
#  74,
#  82,
#  93,
#  76,
#  66,
#  24,
#  89,
#  94,
#  71,
#  92,
#  83,
#  81,
#  30,
#  95,
#  86,
#  79,
#  64,
#  92,
#  93,
#  319,
#  41,
#  84,
#  43,
#  79,
#  99,
#  96,
#  33,
#  80,
#  17,
#  55,
#  50,
#  96,
#  19,
#  62,
#  94,
#  100,
#  25,
#  96,
#  72,
#  70,
#  66,
#  61,
#  43,
#  58,
#  87,
#  80,
#  86,
#  83,
#  57,
#  98,
#  65,
# ...

# %%
cloudiness_list = []
lat_list3 = []

for city in city_data:
    try:
        cloudiness_list.append(city['clouds']['all'])
        lat_list3.append(city['coord']['lat'])
        
    except KeyError:
        None
    

cloudiness_list
# Out:
# [75,
#  75,
#  0,
#  100,
#  74,
#  90,
#  81,
#  1,
#  100,
#  90,
#  75,
#  20,
#  75,
#  90,
#  35,
#  71,
#  22,
#  0,
#  1,
#  0,
#  75,
#  40,
#  75,
#  20,
#  100,
#  75,
#  75,
#  20,
#  20,
#  78,
#  40,
#  75,
#  46,
#  99,
#  0,
#  0,
#  90,
#  100,
#  100,
#  0,
#  1,
#  20,
#  21,
#  0,
#  90,
#  100,
#  64,
#  0,
#  100,
#  100,
#  100,
#  0,
#  40,
#  100,
#  32,
#  5,
#  15,
#  1,
#  0,
#  20,
#  40,
#  0,
#  100,
#  30,
#  98,
#  0,
#  90,
#  75,
#  40,
#  6,
#  10,
#  5,
#  40,
#  0,
#  56,
#  44,
#  14,
#  78,
#  0,
#  51,
#  100,
#  20,
#  90,
#  0,
#  20,
#  100,
#  97,
#  0,
#  40,
#  94,
#  0,
#  26,
#  50,
#  90,
#  100,
#  75,
#  0,
#  57,
#  0,
#  90,
#  100,
#  69,
#  0,
#  40,
#  100,
#  0,
#  76,
#  89,
#  44,
#  11,
#  75,
#  90,
#  93,
#  75,
#  100,
#  97,
#  100,
#  5,
#  100,
#  12,
#  40,
#  1,
#  81,
#  63,
#  1,
#  40,
#  75,
#  0,
#  34,
#  100,
#  40,
#  75,
#  43,
#  100,
#  0,
#  51,
#  95,
#  90,
#  0,
#  0,
#  100,
#  98,
#  0,
#  90,
# ...

# %%
wind_list = []
lat_list4 = []

for city in city_data:
    try:
        wind_list.append(city['wind']['speed'])
        lat_list4.append(city['coord']['lat'])
        
    except KeyError:
        None
    

wind_list
# Out:
# [3.1,
#  1.5,
#  4.16,
#  2.74,
#  3.19,
#  5.1,
#  2.84,
#  3.6,
#  1.57,
#  2.6,
#  9.3,
#  2.1,
#  1,
#  6.7,
#  1.1,
#  1.79,
#  7.76,
#  1.34,
#  7.2,
#  1.5,
#  4.1,
#  4.6,
#  5.1,
#  2.1,
#  0.45,
#  2,
#  4.6,
#  0.5,
#  2.6,
#  3.92,
#  1.5,
#  7.2,
#  4.33,
#  8.52,
#  1.3,
#  2.1,
#  3.6,
#  1.69,
#  1.85,
#  1.17,
#  5.7,
#  7.2,
#  4.82,
#  3,
#  6.7,
#  1.34,
#  2.46,
#  4.1,
#  1.79,
#  0.64,
#  1.45,
#  1.35,
#  7.2,
#  3.35,
#  3.08,
#  1.26,
#  8.27,
#  6.7,
#  2.1,
#  0.5,
#  0.88,
#  2.7,
#  2.65,
#  3,
#  0.83,
#  1.37,
#  2.1,
#  3.1,
#  2.1,
#  8.02,
#  1.49,
#  3.1,
#  5.7,
#  0.5,
#  3.13,
#  5.75,
#  3.58,
#  4.59,
#  1.01,
#  1.94,
#  1.02,
#  1.14,
#  2.27,
#  3.54,
#  2.1,
#  1.24,
#  5.72,
#  1.5,
#  5.91,
#  6.3,
#  4.21,
#  1.13,
#  0.43,
#  2.1,
#  1.7,
#  5.1,
#  2.84,
#  0.83,
#  2.67,
#  5.7,
#  3.42,
#  1.48,
#  1.42,
#  2.6,
#  11.19,
#  1.97,
#  9.41,
#  0.57,
#  3.32,
#  1.5,
#  1.5,
#  3.61,
#  6.66,
#  5.7,
#  3.91,
#  0.2,
#  2.47,
#  6.7,
# ...

# %%
plt.scatter(lat_list, temperature_list, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)

# %%
plt.scatter(lat_list2, humidity_list, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)

# %%
plt.scatter(lat_list3, cloudiness_list, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)

# %%
plt.scatter(lat_list4, wind_list, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
